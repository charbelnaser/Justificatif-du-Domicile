# %%
from faker import Faker
import pytesseract
import re
import spacy
import os
from PIL import ImageFont, ImageDraw, Image ,ImageFilter
import cv2
import random
import numpy as np
import requests
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\charbel.nasr\Tesseract-OCR-New\tesseract.exe'
import textwrap
import string
from skimage import io, util
from PIL import ImageOps
import math
import tensorflow as tf
import matplotlib.pyplot as plt
# %run common_functions.ipynb

# %% [markdown]
# <!-- Arial: "arial.ttf"
# Arial Bold: "arialbd.ttf"
# Arial Italic: "ariali.ttf"
# Arial Bold Italic: "arialbi.ttf"
# Times New Roman: "times.ttf"
# Times New Roman Bold: "timesbd.ttf"
# Times New Roman Italic: "timesi.ttf"
# Times New Roman Bold Italic: "timesbi.ttf"
# Verdana: "verdana.ttf"
# Verdana Bold: "verdanab.ttf"
# Verdana Italic: "verdanai.ttf"
# Verdana Bold Italic: "verdanaz.ttf"
# Courier New: "cour.ttf"
# Courier New Bold: "courbd.ttf"
# Courier New Italic: "couri.ttf"
# Courier New Bold Italic: "courbi.ttf"
# Georgia: "georgia.ttf"
# Georgia Bold: "georgiab.ttf"
# Georgia Italic: "georgiai.ttf"
# Georgia Bold Italic: "georgiaz.ttf" -->

# %% [markdown]
# ### EDF PIL Code

# %%
def get_edf_facture(save_dir,itr):
    dir_path = 'Images générées électricité edf'
    for itr in range(itr):
        # PIL EDF CODE
        fake = Faker('fr_FR')
        name = fake.name()
        first_name = fake.first_name()
        last_name = fake.last_name().upper()
        address = fake.address().upper()
        full_name = last_name +' '+first_name

        response = requests.get(f"https://api.genderize.io?name={full_name.split()[0]}")
        gender = response.json()["gender"]
        if gender == 'female':
            short = 'Mme '
            long = 'Madame '
        else :
            short = 'M. '
            long = 'Monsieur '
        # Open the image
        img = Image.open('Images générées électricité edf\original_edf_élèc.jpg')
        bbox = (1300, 600, 2000, 750)
        x0, y0, x2, y2 = 1300, 600, 2000, 750
        # Draw the bounding box on the image
        # draw = ImageDraw.Draw(img)
        # draw.rectangle(bbox, outline='red', width=3)
        inpainted_img = painte_img_pil(img, 1300, 600, 2000, 750)
        draw = ImageDraw.Draw(inpainted_img)
        font = ImageFont.truetype('courbd.ttf',size=42)

        text1 = f"{short+full_name}\n{address}"
        color = (0, 0, 0)
        dy = 50
        for i, line in enumerate(text1.split('\n')):
            y = y0 + (i)*dy
            draw.text((x0, y), line, fill=color, font=font)
            
        # Text 2
        bbox = (1010, 1185, 1400, 1250)
        x0, y0, x2, y2 = 1010, 1185, 1400, 1250
        # draw.rectangle(bbox, outline='red', width=3)
        inpainted_img = painte_img_pil(inpainted_img, 1045, 1185, 1400, 1250)
        draw = ImageDraw.Draw(inpainted_img)
        text2 = f"{long+last_name+','}"
        font = ImageFont.truetype('arial.ttf',40)
        draw.text((x0+10, y0+10), text2, fill=color, font=font)


        # Text 3
        bbox = (90, 1920, 710, 2025)
        x0, y0, x2, y2 = 90, 1920, 700, 2015
        box_left, box_top, box_right, box_bottom = 90, 1920, 700, 2015
        # draw.rectangle(bbox, outline='red', width=3)
        inpainted_img = painte_img_pil(inpainted_img, 138, 1918, 710, 2025)
        draw = ImageDraw.Draw(inpainted_img)
        text3 = f"{address}"
        color=(115, 115, 115)
        font = ImageFont.truetype('arial.ttf',40)
        draw.text((x0+7, y0), text3, fill=color, font=font)

        # Text 4
        bbox = (90, 2165, 500, 2220)
        x0, y0, x2, y2 = 90, 2165, 500, 2220
        # draw.rectangle(bbox, outline='red', width=3)
        inpainted_img = painte_img_pil(inpainted_img, 120, 2165, 500, 2220)
        draw = ImageDraw.Draw(inpainted_img)
        text4 = f"{short+full_name}"
        color=(115, 115, 115)
        draw.text((x0+10, y0), text4, fill=color, font=font)
        try:
            inpainted_img.save(os.path.join(save_dir, 'my_image_edf_élèctricité_{}.jpg'.format(itr)))
            ImageGenerate(os.path.join(save_dir, 'my_image_edf_élèctricité_{}.jpg'.format(itr)), itr, 'jpg',save_dir)
            put_noise_to_image(save_dir, itr)
            blur_image(save_dir , itr)
        except Exception as e:
            print(f"An error occurred: {e}")

# %% [markdown]
# ## Facture d'élèctricité IBERDROLA

# %%
def get_iberdrola_facture(save_dir,itr):
    dir_path = 'Images générées électricité IBERDROLA'
    for itr in range(itr):
        fake = Faker('fr_FR')
        name = fake.name()
        first_name = fake.first_name()
        last_name = fake.last_name().upper()
        address = fake.address().upper()
        full_name = last_name +' '+first_name
        img = Image.open('Images générées électricité IBERDROLA\oroginale_IBERDROLA.png')

        bbox = (400, 228, 650, 245)
        x0, y0, x2, y2 = 400, 225, 650, 245
        inpainted_img = painte_img_pil(img,400, 230, 650, 245)
        draw = ImageDraw.Draw(inpainted_img)
        text1 = f"{name.upper()}"
        font = ImageFont.truetype('arial.ttf',12)
        color = (0,0,0)
        draw.text((x0+3, y0+5), text1, fill=color, font=font)


        bbox = (400, 260, 650, 290)
        x0, y0, x2, y2 = 400, 260, 650, 290
        draw = ImageDraw.Draw(inpainted_img)
        draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 400, 260, 650, 290)
        draw = ImageDraw.Draw(inpainted_img)
        text2 = f"{address}"
        color = (0, 0, 0)
        dy = 15
        for i, line in enumerate(text2.split('\n')):
            y = y0 + (i)*dy
            draw.text((x0+4, y), line, fill=color, font=font)

        inpainted_img = painte_img_pil(inpainted_img, 525, 335, 720, 365)
        inpainted_img = painte_img_pil(inpainted_img, 400, 365, 510, 350)
        font = ImageFont.truetype("ariblk.ttf", size=9)
        draw = ImageDraw.Draw(inpainted_img)
        # polygon=[(510, 335), (720, 335),(720, 365),(400, 365),(400, 350), (510, 350)]
        # draw.polygon(polygon, outline="red", width=1)
        # draw = ImageDraw.Draw(inpainted_img)
        # Define the two points for the first line of text
        start_point = (510, 335)
        end_point = (720, 335)
        bbox = (510, 335, 720, 335)
        color = (38, 38, 38)
        max_width = 200

        # Measure the width of the text
        text_width, text_height = draw.textsize(text2.replace('\n',''), font)

        # Crop the text if it exceeds the maximum width
        if text_width > max_width:
            # Calculate the maximum number of characters that fit within the maximum width
            num_chars = int(len(text2.replace('\n','')) * max_width / text_width)
            
            # Crop the text
            cropped_text = text2.replace('\n',' ')[:num_chars] 
            remaining_text = text2[num_chars:]
        else:
            cropped_text = text2.replace('\n',' ')
            remaining_text = ""


        draw.text((510, 338), cropped_text, font=font,fill=color)
        draw.text((400, 350), remaining_text, font=font,fill=color)



        font = ImageFont.truetype("arialbd.ttf", size=10)
        color = (38, 38, 38)
        bbox = (100, 252, 200, 270)
        x0, y0, x2, y2 = 100, 252, 200, 270
        draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 108, 252, 220, 267)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+2, y0+2), text1, fill=color, font=font)


        font = ImageFont.truetype("ariblk.ttf", size=8)
        color = (38, 38, 38)
        bbox = (99, 580, 200, 593)
        x0, y0, x2, y2 = 99, 580, 200, 593
        draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 105, 583, 200, 593)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+2, y0+1), text1, fill=color, font = font, thickness=8)

        # draw.text((x0+2, y0+2), text1, fill=color, font=fo
        font = ImageFont.truetype("ariblk.ttf", size=8)
        color = (38, 38, 38)
        bbox = (389, 570, 650, 580)
        x0, y0, x2, y2 = 389, 570, 650, 580
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 389, 570, 650, 580)
        draw = ImageDraw.Draw(inpainted_img)

        draw.text((x0+2, y0), address.replace('\n',''), fill=color, font = font, thickness=8)

        inpainted_img.save(os.path.join(save_dir, 'my_image_iberdrola_élèctricité_{}.jpg'.format(itr)))
        ImageGenerate(os.path.join(save_dir, 'my_image_iberdrola_élèctricité_{}.jpg'.format(itr)), itr, 'jpg',save_dir)
        put_noise_to_image(save_dir, itr)
        blur_image(save_dir , itr)

# %% [markdown]
# ## Facture d'élèctricité Engie

# %%
def get_engie_facture(save_dir,itr):
    dir_path = 'Images générées électricité Engie'
    for itr in range(itr):
        fake = Faker('fr_FR')
        name = fake.name()
        first_name = fake.first_name()
        last_name = fake.last_name().upper()
        address = fake.address().upper()
        full_name = last_name +' '+first_name
        img = Image.open('Images générées électricité Engie\original_engie_facture.jpg')
        response = requests.get(f"https://api.genderize.io?name={full_name.split()[0]}")
        gender = response.json()["gender"]
        thickness = 1
        if gender == 'female':
            short = 'Mme '
            long = 'Madame '
        else :
            short = 'M '
            long = 'Monsieur '
        text1 = f"{short+full_name}\n{address}"
        bbox = (720, 300, 1080, 410)
        x0, y0, x2, y2 = 720, 300, 1080, 410
        # draw = ImageDraw.Draw(img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(img, 720, 300, 1080, 410)
        font = ImageFont.truetype("arialbd.ttf", size=28)
        color = (51, 51, 51)
        draw = ImageDraw.Draw(inpainted_img)
        dy = 30
        for i, line in enumerate(text1.split('\n')):
            y = y0 + (i)*dy
            draw.text((x0+4, y), line, fill=color, font=font)


        text2 = f"{address}"
        color = (38, 38, 38)
        bbox = (150, 630, 350, 670)
        x0, y0, x2, y2 = 150, 630, 350, 670
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 150, 630, 350, 670)
        draw = ImageDraw.Draw(inpainted_img)
        font = ImageFont.truetype("arialbd.ttf", size=15)
        draw.text((x0, y0), text2, fill=color, font=font)


        text3 = f"{short+full_name}"
        color = (51, 51, 51)
        bbox = (465, 1745, 700, 1770)
        font = ImageFont.truetype("arialbd.ttf", size=18)
        x0, y0, x2, y2 = 465, 1745, 700, 1770
        draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 475, 1745, 700, 1770)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+3, y0+1),fake.iban(), fill=color, font=font)


        # Générer un identifiant Créancier SEPA
        ics = 'FR' + fake.swift11()
        text4 = f"{ics}"
        color = (51, 51, 51)
        bbox = (465, 1800, 700, 1832)
        font = ImageFont.truetype("arialbd.ttf", size=20)
        x0, y0, x2, y2 = 465, 1800, 700, 1832
        draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 480, 1800, 700, 1830)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+3, y0+5), text4, fill=color, font=font)


        # Liste de noms de banques en France
        bank_names = ['BNP Paribas', 'Société Générale', 'Crédit Agricole', 'Crédit Mutuel', 'Banque Populaire', 'Caisse d’Epargne', 'La Banque Postale', 'HSBC France', 'Boursorama', 'AXA Banque', 'Natixis', 'Banque Palatine']
        # Générer un nom de banque aléatoire
        random_bank_name = random.choice(bank_names)
        text5 = f"{'BANQUE '+random_bank_name}"
        bbox = (210, 1850, 700, 1872)
        font = ImageFont.truetype("arialbd.ttf", size=20)
        x0, y0, x2, y2 = 210, 1850, 700, 1872
        draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 210, 1855, 700, 1872)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+5, y0+5), text5, fill=color, font=font)

        # Generate a list of 6 random letters
        letters = [random.choice('ABCDEFGHIJKLMNOPQRSTUVWXYZ') for _ in range(4)]
        # Generate a list of 6 random digits
        digits = [random.choice('0123456789') for _ in range(12)]
        # Shuffle the letters and digits lists
        random.shuffle(letters)
        random.shuffle(digits)
        # Combine the shuffled lists to create the final 12-character string
        result = ''.join(letters + digits)

        font = ImageFont.truetype("arialbd.ttf", size=20)
        bbox = (1125, 1805, 1300, 1830)
        x0, y0, x2, y2 = 1125, 1805, 1300, 1830
        draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 1136, 1805, 1300, 1830)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+3, y0), result , fill=color, font=font)


        font = ImageFont.truetype("arialbd.ttf", size=20)
        iban = fake.iban()
        bbox = (840, 1855, 1200, 1872)
        x0, y0, x2, y2 = 840, 1855, 1200, 1872
        draw = ImageDraw.Draw(inpainted_img)
        draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 840, 1855, 1200, 1872)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+3, y0), iban, fill=color, font=font)

        inpainted_img.save(os.path.join(save_dir, 'my_image_engie_élèctricité_{}.jpg'.format(itr)))
        ImageGenerate(os.path.join(save_dir, 'my_image_engie_élèctricité_{}.jpg'.format(itr)),itr,'jpg', save_dir)
        put_noise_to_image(save_dir, itr)
        blur_image(save_dir , itr)

# %% [markdown]
# ## Eni Facture d'élèctricité

# %%
def get_enie_facture(save_dir,itr):
    dir_path = 'Images générées électricité Enie'
    for itr in range(itr):
        fake = Faker('fr_FR')
        name = fake.name()
        first_name = fake.first_name()
        last_name = fake.last_name().upper()
        address = fake.address().upper()
        full_name = last_name +' '+first_name
        img = Image.open('Images générées électricité Enie\original-eni-facture.jpg')
        response = requests.get(f"https://api.genderize.io?name={full_name.split()[0]}")
        gender = response.json()["gender"]
        thickness = 1
        if gender == 'female':
            short = 'Mme '
            long = 'Madame '
        else :
            short = 'M '
            long = 'Monsieur '

        font = ImageFont.truetype("calibrib.ttf", size=14)
        color = (51, 51, 51)
        bbox = (45, 45, 140, 55)
        x0, y0, x2, y2 = 45, 45, 140, 55
        # draw = ImageDraw.Draw(img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(img, 46, 45, 140, 55)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0, y0), str(fake.random_number(digits=12)), fill=color, font=font)

        font = ImageFont.truetype("calibri.ttf", size=14)
        bbox = (320, 150, 440, 200)
        x0, y0, x2, y2 = 320, 150, 440, 200
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 320, 150, 440, 200)
        text1 = f"{long+full_name}\n{address}"
        draw = ImageDraw.Draw(inpainted_img)
        dy = 14
        for i, line in enumerate(text1.split('\n')):
            y = y0 + (i)*dy
            draw.text((x0, y), line, fill=color, font=font)

        font = ImageFont.truetype("calibrib.ttf", size=12)
        bbox = (125, 330, 200, 345)
        x0, y0, x2, y2 = 125, 330, 200, 345
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 131, 332, 200, 345)
        draw = ImageDraw.Draw(inpainted_img)
        # Generate a random list of 12 characters that combines uppercase letters and digits
        characters = [random.choice('ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789') for _ in range(12)]
        # Shuffle the list of characters
        random.shuffle(characters)
        # Combine the shuffled list to create the final 12-character string
        result = ''.join(characters)
        draw.text((x0+2, y0+2), result, fill=color, font=font)


        font = ImageFont.truetype("calibrib.ttf", size=10)
        bbox = (175, 378, 300, 388)
        x0, y0, x2, y2 = 175, 378, 300, 388
        draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 179, 378, 300, 388)
        draw = ImageDraw.Draw(inpainted_img)
        # Generate a list of 6 random letters
        letters = [random.choice('ABCDEFGHIJKLMNOPQRSTUVWXYZ') for _ in range(4)]
        # Generate a list of 6 random digits
        digits = [random.choice('0123456789') for _ in range(12)]
        # Shuffle the letters and digits lists
        random.shuffle(letters)
        random.shuffle(digits)
        # Combine the shuffled lists to create the final 12-character string
        result = ''.join(letters + digits)
        draw.text((x0+1, y0), result, fill=color, font=font)
        
        font = ImageFont.truetype("calibrib.ttf", size=10)
        bbox = (43, 450, 200, 475)
        x0, y0, x2, y2 = 43, 450, 200, 475
        adress = f"{address}"
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 43, 451, 200, 475)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+2, y0), adress, fill=color, font=font)

        font = ImageFont.truetype("calibrib.ttf", size=14)
        bbox = (43, 490, 200, 505)
        x0, y0, x2, y2 = 43, 490, 200, 505
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 43, 490, 200, 500)
        fourteen_digit_number = random.randint(10**13, (10**14)-1)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+2, y0), str(fourteen_digit_number), fill=color, font=font)

        font = ImageFont.truetype("calibrib.ttf", size=12)
        bbox = (100, 505, 150, 515)
        x0, y0, x2, y2 = 100, 505, 150, 515
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        letters = [random.choice('ABCDEFGHIJKLMNOPQRSTUVWXYZ') for _ in range(1)]
        # Generate a list of 6 random digits
        digits = [random.choice('0123456789') for _ in range(3)]
        # Shuffle the letters and digits lists
        random.shuffle(letters)
        random.shuffle(digits)
        # Combine the shuffled lists to create the final 12-character string
        result = ''.join(letters + digits)
        inpainted_img = painte_img_pil(inpainted_img, 103, 505, 150, 515)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+2, y0), str(result), fill = color, font = font)


        font = ImageFont.truetype("calibrib.ttf", size=12)
        bbox = (350, 778, 470, 790)
        x0, y0, x2, y2 = 350, 778, 470, 790
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 357, 778, 470, 790)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+5, y0+1), str(fake.iban()), fill = color, font = font)
        
        inpainted_img.save(os.path.join(save_dir, 'my_image_ekwateur_élèctricité_{}.jpg'.format(itr)))
        ImageGenerate(os.path.join(save_dir, 'my_image_ekwateur_élèctricité_{}.jpg'.format(itr)),itr,'jpg',save_dir)
        put_noise_to_image(save_dir, itr)
        blur_image(save_dir , itr)

# %% [markdown]
# ## Total Facture D'élèctricité

# %%
def get_total_facture(save_dir,itr):
    dir_path = 'Images générées électricité total'
    for itr in range(itr):
        fake = Faker('fr_FR')
        name = fake.name()
        first_name = fake.first_name()
        last_name = fake.last_name().upper()
        address = fake.address().upper()
        full_name = last_name +' '+first_name
        img = Image.open('Images générées électricité total\original_total_élè.jpg')
        response = requests.get(f"https://api.genderize.io?name={full_name.split()[0]}")
        gender = response.json()["gender"]
        thickness = 1
        if gender == 'female':
            short = 'Mme '
            long = 'Madame '
        else :
            short = 'M '
            long = 'Monsieur '
            
        color = (0, 0, 0)
        font = ImageFont.truetype("arial.ttf", size=18)
        bbox = (180, 257, 500, 280)
        x0, y0, x2, y2 = 180, 257, 500, 280
        # draw = ImageDraw.Draw(img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(img, 187, 257, 500, 280)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0, y0+2), full_name, fill=color, font=font)

        bbox = (52, 300, 350, 345)
        x0, y0, x2, y2 = 52, 300, 350, 345
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(img, 52, 300, 350, 345)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0, y0+2), address, fill=color, font=font)

        font = ImageFont.truetype("arialbd.ttf", size=20)
        bbox = (660, 360, 1000, 380)
        x0, y0, x2, y2 = 660, 360, 1000, 380
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(img, 660, 360, 1000, 380)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0, y0+2), short+' '+full_name, fill=color, font=font)


        bbox = (660, 385, 1000, 460)
        x0, y0, x2, y2 = 660, 385, 1000, 460
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 660, 385, 1000, 460)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0, y0+2), address, fill=color, font=font)


        font = ImageFont.truetype("arial.ttf", size=18)
        bbox = (268, 1505, 500, 1530)
        x0, y0, x2, y2 = 268, 1505, 500, 1520
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 268, 1505, 500, 1530)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0+2, y0+2), full_name, fill=color, font=font)
        inpainted_img.save(os.path.join(save_dir, 'my_image_total_élèctricité_{}.jpg'.format(itr)))
        ImageGenerate(os.path.join(save_dir, 'my_image_total_élèctricité_{}.jpg'.format(itr)), itr,'jpg',save_dir)
        put_noise_to_image(save_dir, itr)
        blur_image(save_dir , itr)

# %% [markdown]
# ## Séolis Electicité

# %%
def get_séolis_facture(save_dir,itr):
    dir_path = 'Images générées électricité Seolis'
    for itr in range(itr):
        fake = Faker('fr_FR')
        name = fake.name()
        first_name = fake.first_name()
        last_name = fake.last_name().upper()
        address = fake.address().upper()
        full_name = last_name +' '+first_name
        img = Image.open('Images générées électricité Seolis\original_seolis.jpg')
        response = requests.get(f"https://api.genderize.io?name={full_name.split()[0]}")
        gender = response.json()["gender"]
        thickness = 1
        if gender == 'female':
            short = 'Mme '
            long = 'Madame '
        else :
            short = 'M '
            long = 'Monsieur '

        color=(51, 51, 51)
        font = ImageFont.truetype("arialbd.ttf", size=11)
        bbox = (338, 132, 500, 170)
        x0, y0, x2, y2 = 338, 132, 500, 170   
        # draw = ImageDraw.Draw(img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(img, 338, 132, 500, 170)
        draw = ImageDraw.Draw(inpainted_img)
        text1 = f"{short+full_name}\n{address}"
        dy=11
        for i, line in enumerate(text1.split('\n')):
            y = y0 + (i)*dy
            draw.text((x0, y), line, fill=color, font=font)


        color=(0, 0, 0)
        font = ImageFont.truetype("arialbd.ttf", size=8)
        bbox = (190, 245, 280, 280)
        x0, y0, x2, y2 = 190, 245, 280, 280
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 180, 244, 280, 280)
        draw = ImageDraw.Draw(inpainted_img)
        text1 = f"{short+full_name}\n{address}"
        dy=9
        for i, line in enumerate(text1.split('\n')):
            y = y0 + (i)*dy
            draw.text((x0, y), line, fill=color, font=font)

        inpainted_img.save(os.path.join(save_dir, 'my_image_seolis_élèctricité_{}.jpg'.format(itr)))
        ImageGenerate(os.path.join(save_dir, 'my_image_seolis_élèctricité_{}.jpg'.format(itr)), itr, 'jpg',save_dir)
        put_noise_to_image(save_dir, itr)
        blur_image(save_dir , itr)

# %%
# arial.ttf
# arialbd.ttf
# arialbi.ttf
# ariali.ttf
# DejaVuSans-Bold.ttf
# DejaVuSans.ttf
# DejaVuSansMono-Bold.ttf
# DejaVuSansMono.ttf
# DejaVuSerif-Bold.ttf
# DejaVuSerif.ttf
# FreeMono.ttf
# FreeMonoBold.ttf
# FreeSans.ttf
# FreeSansBold.ttf
# FreeSerif.ttf
# FreeSerifBold.ttf
# LiberationMono-Bold.ttf
# LiberationMono-Regular.ttf
# LiberationSans-Bold.ttf
# LiberationSans-Regular.ttf
# LiberationSerif-Bold.ttf
# LiberationSerif-Regular.ttf
# NotoMono-Regular.ttf
# NotoSans-Bold.ttf
# NotoSans-BoldItalic.ttf
# NotoSans-Italic.ttf
# NotoSans-Regular.ttf
# NotoSerif-Bold.ttf
# NotoSerif-Regular.ttf

# %% [markdown]
# ## Ekwateur

# %%
def get_ekwateur_facture(save_dir,itr):
    dir_path = 'Images générées électricité ekwateur'
    for itr in range(itr):
        fake = Faker('fr_FR')
        name = fake.name()
        first_name = fake.first_name()
        last_name = fake.last_name().upper()
        address = fake.address().upper()
        full_name = last_name +' '+first_name
        img = Image.open('Images générées électricité ekwateur/original-ekwateur-facture.jpg')
        response = requests.get(f"https://api.genderize.io?name={full_name.split()[0]}")
        gender = response.json()["gender"]
        thickness = 1
        if gender == 'female':
            short = 'Mme '
            long = 'Madame '
        else :
            short = 'MR '
            long = 'Monsieur '

        # Full adress 1
        color=(0, 0, 0)
        font = ImageFont.truetype("arial.ttf", size=11)
        bbox = (336, 157, 397, 214)
        x0, y0, x2, y2 = 336, 157, 397, 214
        # draw = ImageDraw.Draw(img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(img, 336, 157, 397, 214)
        draw = ImageDraw.Draw(inpainted_img)
        text1 = f"{short+full_name}\n{address}"
        dy=16
        for i, line in enumerate(text1.split('\n')):
            y = y0 + (i)*dy
            draw.text((x0, y), line, fill=color, font=font)

        # Contact
        color=(0, 0, 0)
        font = ImageFont.truetype("arial.ttf", size=11)
        bbox = (49, 168, 102, 182)
        x0, y0, x2, y2 = 49, 168, 102, 182
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 52, 168, 102, 182)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0, y0), short+full_name, fill=color, font=font)


        # Adress 2
        color=(0, 0, 0)
        font = ImageFont.truetype("arial.ttf", size=11)
        bbox = (46, 198, 104, 226)
        x0, y0, x2, y2 = 46, 198, 104, 226
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 58, 198, 104, 226)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0, y0), address, fill=color, font=font)

        # PDL
        color=(0, 0, 0)
        font = ImageFont.truetype("arial.ttf", size=11)
        bbox = (46, 270, 135, 277)
        x0, y0, x2, y2 = 46, 270, 135, 277
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 48, 270, 145, 277)
        draw = ImageDraw.Draw(inpainted_img)
        # Generate a fake PDL number
        pdl_prefix = 'FR'
        pdl_digits = fake.random_number(digits=14)
        fake_pdl = pdl_prefix + str(pdl_digits)
        draw.text((x0+2, y0), fake_pdl, fill=color, font=font)

        # Client Réference
        color=(0, 0, 0)
        font = ImageFont.truetype("arial.ttf", size=11)
        bbox = (418, 292, 452, 302)
        x0, y0, x2, y2 = 418, 292, 452, 302
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 420, 292, 452, 302)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0, y0), str(fake.random_number(digits=6)), fill=color, font=font)

        # Réference Contrat 
        color=(0, 0, 0)
        font = ImageFont.truetype("arial.ttf", size=11)
        bbox = (402, 307, 458, 316)
        x0, y0, x2, y2 = 402, 307, 458, 316
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 406, 307, 458, 316)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0, y0), str(fake.random_number(digits=9)), fill=color, font=font)

        # Email
        color=(0, 0, 0)
        font = ImageFont.truetype("arial.ttf", size=11)
        bbox = (436, 280, 502, 289)
        x0, y0, x2, y2 = 436, 280, 502, 289
        draw.text((x0, y0-2), generate_random_email(first_name,last_name), fill=color, font=font)

        # Compteur
        color=(0, 0, 0)
        font = ImageFont.truetype("arial.ttf", size=11)
        bbox = (151, 284, 163, 294)
        x0, y0, x2, y2 = 151, 284, 163, 294
        # draw = ImageDraw.Draw(inpainted_img)
        # draw.rectangle(bbox, outline='red', width=1)
        inpainted_img = painte_img_pil(inpainted_img, 155, 284, 163, 294)
        draw = ImageDraw.Draw(inpainted_img)
        draw.text((x0, y0-2), str(fake.random_number(digits=3)), fill=color, font=font)

        inpainted_img.save(os.path.join(save_dir, 'my_image_ekwateur_élèctricité_{}.jpg'.format(itr)))
        ImageGenerate(os.path.join(save_dir, 'my_image_ekwateur_élèctricité_{}.jpg'.format(itr)), itr,'jpg',save_dir)
        put_noise_to_image(save_dir, itr)
        blur_image(save_dir , itr)

# %% [markdown]
# ## vantefall facture

# %%
# fake = Faker('fr_FR')
# name = fake.name()
# first_name = fake.first_name()
# last_name = fake.last_name().upper()
# address = fake.address().upper()
# full_name = last_name +' '+first_name
# img = Image.open('Images générées éléctricié Vantefall/original-facture-vatenfall.png')
# response = requests.get(f"https://api.genderize.io?name={full_name.split()[0]}")
# gender = response.json()["gender"]
# thickness = 1
# if gender == 'female':
#     short = 'Mme '
#     long = 'Madame '
# else :
#     short = 'M '
#     long = 'Monsieur '

# # Full adress 1
# color=(0, 0, 0)
# font = ImageFont.truetype("arialbd.ttf", size=13)
# bbox = (394, 144, 702, 254)
# x0, y0, x2, y2 = 394, 144, 702, 254
# draw = ImageDraw.Draw(img)
# draw.rectangle(bbox, outline='red', width=1)
# inpainted_img = painte_img_pil(img, 394, 144, 702, 254)
# draw = ImageDraw.Draw(inpainted_img)
# text1 = f"{short+full_name}\n{address}"
# dy=16
# for i, line in enumerate(text1.split('\n')):
#     y = y0 + (i)*dy
#     draw.text((x0, y), line, fill=color, font=font)
# dir_path='Images générées éléctricié Vantefall'
# inpainted_img.save(os.path.join(dir_path, 'my_image_vantefall_élèctricité.jpg'))
# inpainted_img.show()

# %%
 # PIL EDF CODE
# fake = Faker('fr_FR')
# name = fake.name()
# first_name = fake.first_name()
# last_name = fake.last_name().upper()
# address = fake.address().upper()
# full_name = last_name +' '+first_name

# response = requests.get(f"https://api.genderize.io?name={full_name.split()[0]}")
# gender = response.json()["gender"]
# if gender == 'female':
#     short = 'Mme '
#     long = 'Madame '
# else :
#     short = 'M. '
#     long = 'Monsieur '
# # Open the image
# img = Image.open('Images générées électricité edf\original_edf_élèc.jpg')
# bbox = (1300, 600, 2000, 750)
# x0, y0, x2, y2 = 1300, 600, 2000, 750
# # Draw the bounding box on the image
# # draw = ImageDraw.Draw(img)
# # draw.rectangle(bbox, outline='red', width=3)
# inpainted_img = painte_img_pil(img, 1300, 600, 2000, 750)
# draw = ImageDraw.Draw(inpainted_img)
# font = ImageFont.truetype('courbd.ttf',size=42)

# text1 = f"{short+full_name}\n{address}"
# color = (0, 0, 0)
# dy = 50
# for i, line in enumerate(text1.split('\n')):
#     y = y0 + (i)*dy
#     #draw.text((x0, y), line, fill=color, font=font)
    
# # Text 2
# bbox = (1010, 1185, 1400, 1250)
# x0, y0, x2, y2 = 1010, 1185, 1400, 1250
# # draw.rectangle(bbox, outline='red', width=3)
# inpainted_img = painte_img_pil(inpainted_img, 1045, 1185, 1400, 1250)
# draw = ImageDraw.Draw(inpainted_img)
# text2 = f"{long+last_name+','}"
# font = ImageFont.truetype('arial.ttf',40)
# #draw.text((x0+10, y0+10), text2, fill=color, font=font)


# # Text 3
# bbox = (90, 1920, 710, 2025)
# x0, y0, x2, y2 = 90, 1920, 700, 2015
# box_left, box_top, box_right, box_bottom = 90, 1920, 700, 2015
# # draw.rectangle(bbox, outline='red', width=3)
# inpainted_img = painte_img_pil(inpainted_img, 138, 1918, 710, 2025)
# draw = ImageDraw.Draw(inpainted_img)
# text3 = f"{address}"
# color=(115, 115, 115)
# font = ImageFont.truetype('arial.ttf',40)
# #draw.text((x0+7, y0), text3, fill=color, font=font)

# # Text 4
# bbox = (90, 2165, 500, 2220)
# x0, y0, x2, y2 = 90, 2165, 500, 2220
# # draw.rectangle(bbox, outline='red', width=3)
# inpainted_img = painte_img_pil(inpainted_img, 120, 2165, 500, 2220)
# draw = ImageDraw.Draw(inpainted_img)
# text4 = f"{short+full_name}"
# color=(115, 115, 115)
# #draw.text((x0+10, y0), text4, fill=color, font=font)
# inpainted_img.show()
# inpainted_img.save('image_supp.jpg')
